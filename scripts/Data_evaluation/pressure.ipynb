# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-06-06*

# %%
import sys
sys.path.append('../../src/')
import ModelEvaLib as me
from namelist import *

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'PRES'
varch = '气压'

title = 'Pressure'
units = 'hPa'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(presrhfile,var,shpall,obsall,varch)
# Out:
# Get the PRES in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1001.548057
# 1  sim mean   984.713867
# 2         R     0.985889
# 3        MB   -16.834189
# 4      RMSE    16.850423
# 5       IOA     0.344941

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(presrhfile,var,shpurban,obsurban,varch)
# Out:
# Get the PRES in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1005.850056
# 1  sim mean  1005.441711
# 2         R     0.981436
# 3        MB    -0.408345
# 4      RMSE     0.921993
# 5       IOA     0.988380

# %% [markdown]
# 郊区或通道区的范围不好处理，因此以下暂不考虑
# ## 安庆市通道区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/channel.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PRES in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1013.459048
# 1  sim mean   996.526123
# 2         R     0.992212
# 3        MB   -16.932925
# 4      RMSE    16.952261
# 5       IOA     0.428745
